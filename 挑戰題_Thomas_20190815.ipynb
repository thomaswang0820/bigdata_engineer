# %%
# 請使用print函數印出下列結果
# 輸出內容需相同
# hint: for迴圈
# hint: range(10,0,-1)
# 注意樹的頂端是星星
# ＝數量不同可接受，但是星星與o符號的數量每一列都需相同

for x in range(1,12):
    if x >= 9:
        print("=====  ",end='')
        for y in range(x):
            print('*     ', end='')
    else:
        print("       ",end='')
        for y in range(x):
            print('*     ', end='')
    print('')
    
for b in range(10,0,-1):
    if b >= 8:
        print("=====  ",end='')
        for c in range(b):
            print('o     ', end='')
    else:
        print("       ",end='')
        for c in range(b):
            print('o     ', end='')
    print('')
# Out:
#        *
#        *     *
#        *     *     *
#        *     *     *     *
#        *     *     *     *     *
#        *     *     *     *     *     *
#        *     *     *     *     *     *     *
#        *     *     *     *     *     *     *     *
# =====  *     *     *     *     *     *     *     *     *
# =====  *     *     *     *     *     *     *     *     *     *
# =====  *     *     *     *     *     *     *     *     *     *     *
# =====  o     o     o     o     o     o     o     o     o     o
# =====  o     o     o     o     o     o     o     o     o
# =====  o     o     o     o     o     o     o     o
#        o     o     o     o     o     o     o
#        o     o     o     o     o     o
#        o     o     o     o     o
#        o     o     o     o
#        o     o     o
#        o     o
#        o

# %%
# 挑戰題二
# hint: for
# hint: sum()
# hint: range(len(data))
    
data = [{'jobType': '1', 'jobNo': '7154668', 'jobName': '北區醫院醫藥代表/專員', 'jobNameSnippet': '北區醫院醫藥代表/專員', 'jobRole': '1', 'jobRo': '1', 'jobAddrNoDesc': '台北市大安區', 'jobAddress': '(依照公司規定分派)', 'description': '大專以上程度，醫藥、護理相關科系尤佳。一年以上相關業務經驗或有醫療通路臨床經驗。有醫療市場行銷業務推廣經驗或有興趣者。個性特質積極、主動、有目標意識，喜歡與人互動，有關懷與分享的特質，溝通協調能力佳，抗壓性高。熟Ms-Office電腦操作。負責台北地區醫院通路藥品、保健品銷售與推廣。【須自備汽車】\r\n※享有基本月薪保障及季獎金', 'optionEdu': '專科', 'period': '00', 'periodDesc': '經歷不拘', 'applyCnt': '00071', 'applyDesc': '30人以上應徵', 'custNo': '22180049000', 'custName': '天義企業股份有限公司', 'coIndustry': '', 'coIndustryDesc': '', 'salaryLow': '0040000', 'salaryHigh': '0050000', 'salaryDesc': '月薪 40,000~50,000元', 's10': '50', 'appearDate': '20190727', 'appearDateDesc': '7/27', 'optionZone': '4096', 'isApply': '0', 'applyDate': '', 'isSave': '0', 'descSnippet': '大專以上程度，醫藥、護理相關科系尤佳。一年以上相關業務經驗或有醫療通路臨床經驗。有醫療市場行銷業務推廣經驗或有興趣者。個性特質積極、主動、有目標意識，喜歡與人互動，有關懷與分享的特質，溝通協調能力佳，抗壓性高。熟Ms-Office電腦操作。負責台北地區醫院通路藥品、保健品銷售與推廣。【須自備汽車】\r\n※享有基本月薪保障及季獎金', 'tags': [], 'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis?j=523c45273a6e415833343c655830396193a3c466e3e5e4023232323203c2d2827563j50&channel=104rpt&jobsource=hotjob_chr', 'job': '//www.104.com.tw/job/49cks?jobsource=hotjob_chr', 'cust': '//www.104.com.tw/company/a6tffc8?jobsource=hotjob_chr'}, 'jobsource': 'hotjob_chr', 'jobNameRaw': '北區醫院醫藥代表/專員', 'custNameRaw': '天義企業股份有限公司'}, {'jobType': '1', 'jobNo': '5523683', 'j
.休假說明: 週休二日，週六需配合輪班(提供加班費或補休)，1個月大約1-2次。', 'optionEdu': '高中', 'period': '00', 'periodDesc': '經歷不拘', 'applyCnt': '00278', 'applyDesc': '30人以上應徵', 'custNo': '130000000069056', 'custName': '感謝愛股份有限公司', 'coIndustry': '', 'coIndustryDesc': '', 'salaryLow': '0028000', 'salaryHigh': '0035000', 'salaryDesc': '月薪 28,000~35,000元', 's10': '50', 'appearDate': '20190730', 'appearDateDesc': '7/30', 'optionZone': '64', 'isApply': '0', 'applyDate': '', 'isSave': '0', 'descSnippet': '1.協助現場及電話客戶服務 \r\n2.提供正確有效率之訂貨、出貨服務 \r\n3.解決顧客問題和處理抱怨相關事宜\r\n4.負責公司營運行政作業,訂單及發票開立,入會資料處理等 \r\n5.系統資料流程規劃處理具文書處理能力 \r\n6.具親和力及良好溝通技巧\r\n＊負責公司行政工作人員，無須對外銷售商品。\r\n7.休假說明: 週休二日，週六需配合輪班(提供加班費或補休)，1個月大約1-2次。', 'tags': ['外商公司'], 'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis?j=435149305d7350294b3941284b353d6643f4149723b3d456e434941242424241f24b41493816j51&channel=104rpt&jobsource=hotjob_chr', 'job': '//www.104.com.tw/job/4pkh7?jobsource=hotjob_chr', 'cust': '//www.104.com.tw/company/1a2x6bjglc?jobsource=hotjob_chr'}, 'jobsource': 'hotjob_chr', 'jobNameRaw': '行政客服專員(月薪28k~35k)', 'custNameRaw': '感謝愛股份有限公司'}]

candidate = data[0]
candidate_key = []
for each_key in candidate.keys():
        candidate_key.append(each_key)
print("data裡面dict的key有:", candidate_key)

print("")
print("============================================================")
print("")

salary_low = []
for x in data:
    x['salaryLow'] = int(x['salaryLow'])
    salary_low.append(x['salaryLow'])

print("salaryLow的平均為:",(sum(salary_low) / len(salary_low)))

print("")
print("============================================================")
print("")

salary_high = []
for y in data:
    y['salaryHigh'] = int(y['salaryHigh'])
    salary_high.append(y['salaryHigh'])

print("salaryHigh的平均為:",(sum(salary_high) / len(salary_high)))

print("")
print("============================================================")
print("")

job_name = []

for z in data:
    job_name.append(z['jobName'])
print("data裡的工作名稱有:", job_name)

print("")
print("============================================================")
print("")

job_addr = []

for t in data:
    job_addr.append(t['jobAddrNoDesc'])
print("data裡的工作區域分別為:", job_addr)
# Out:
# data裡面dict的key有: ['jobType', 'jobNo', 'jobName', 'jobNameSnippet', 'jobRole', 'jobRo', 'jobAddrNoDesc', 'jobAddress', 'description', 'optionEdu', 'period', 'periodDesc', 'applyCnt', 'applyDesc', 'custNo', 'custName', 'coIndustry', 'coIndustryDesc', 'salaryLow', 'salaryHigh', 'salaryDesc', 's10', 'appearDate', 'appearDateDesc', 'optionZone', 'isApply', 'applyDate', 'isSave', 'descSnippet', 'tags', 'link', 'jobsource', 'jobNameRaw', 'custNameRaw']
#
# ...
#
# salaryLow的平均為: 24000.0
#
# ...
#
# salaryHigh的平均為: 29500.0
#
# ...
#
# data裡的工作名稱有: ['北區醫院醫藥代表/專員', '【保障9個月45萬】300萬培訓新手變專業，最快1年3個月升店長！(2019年前進杜拜✈✈)', '法務助理/法務人員', '行政客服專員(月薪28k~35k)']
#
# ...
#
# data裡的工作區域分別為: ['台北市大安區', '台北市大安區', '台北市內湖區', '台北市大同區']
